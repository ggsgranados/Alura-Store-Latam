# %% [markdown]
# <a href="https://colab.research.google.com/github/ggsgranados/Alura-Store-Latam/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import folium
import seaborn as sns

# %% [markdown]
# ### Importación de datos

# %%
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ingresos_tienda1 = tienda['Precio'].sum()
print('Ingresos totales de la tienda 1: '+ str(ingresos_tienda1))
# Out:
# Ingresos totales de la tienda 1: 1150880400.0

# %%
ingresos_tienda2 = tienda2['Precio'].sum()
print('Ingresos totales de la tienda 2: '+ str(ingresos_tienda2))
# Out:
# Ingresos totales de la tienda 2: 1116343500.0

# %%
ingresos_tienda3 = tienda3['Precio'].sum()
print('Ingresos totales de la tienda 3: '+ str(ingresos_tienda3))
# Out:
# Ingresos totales de la tienda 3: 1098019600.0

# %%
ingresos_tienda4 = tienda4['Precio'].sum()
print('Ingresos totales de la tienda 4: '+ str(ingresos_tienda4))
# Out:
# Ingresos totales de la tienda 4: 1038375700.0

# %%
# Datos para el gráfico de barras
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ingresos = [ingresos_tienda1, ingresos_tienda2, ingresos_tienda3, ingresos_tienda4]
colores = ['skyblue', 'gold', 'lightgreen', 'lightcoral']

# Crear el gráfico de barras
plt.figure(figsize=(8, 6))
plt.bar(tiendas, ingresos, color=colores)

# Añadir etiquetas y título
plt.xlabel('Tienda')
plt.ylabel('Ingresos Totales (mil millones)')
plt.title('Ingresos Totales por Tienda')

# Añadir una cuadrícula horizontal para facilitar la lectura
plt.grid(axis='y', linestyle='--')

# Ajustar el diseño para evitar que las etiquetas se superpongan
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
# Cuenta la frecuencia de cada categoría en la columna 'Categoría del Producto'
ventas_por_categoria_tienda1 = tienda['Categoría del Producto'].value_counts()

# Imprime las categorías y sus conteos
print("Ventas por categorías de la Tienda 1:")
print(ventas_por_categoria_tienda1)
# Out:
# Ventas por categorías de la Tienda 1:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
# Cuenta la frecuencia de cada categoría en la columna 'Categoría del Producto'
ventas_por_categoria_tienda2 = tienda2['Categoría del Producto'].value_counts()

# Imprime las categorías y sus conteos
print("Ventas por categorías de la Tienda 2:")
print(ventas_por_categoria_tienda2)
# Out:
# Ventas por categorías de la Tienda 2:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
# Cuenta la frecuencia de cada categoría en la columna 'Categoría del Producto'
ventas_por_categoria_tienda3 = tienda3['Categoría del Producto'].value_counts()

# Imprime las categorías y sus conteos
print("Ventas por categorías de la Tienda 3:")
print(ventas_por_categoria_tienda3)
# Out:
# Ventas por categorías de la Tienda 3:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
# Cuenta la frecuencia de cada categoría en la columna 'Categoría del Producto'
ventas_por_categoria_tienda4 = tienda4['Categoría del Producto'].value_counts()

# Imprime las categorías y sus conteos
print("Ventas por categorías de la Tienda 4:")
print(ventas_por_categoria_tienda4)
# Out:
# Ventas por categorías de la Tienda 4:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
# Obtener las categorías únicas y ordenarlas
categorias_tienda1 = ventas_por_categoria_tienda1.index.tolist()
categorias_tienda2 = ventas_por_categoria_tienda2.index.tolist()
categorias_tienda3 = ventas_por_categoria_tienda3.index.tolist()
categorias_tienda4 = ventas_por_categoria_tienda4.index.tolist()
categorias_unicas = sorted(list(set(categorias_tienda1 + categorias_tienda2 + categorias_tienda3 + categorias_tienda4)))

# Asegurar que todas las series tengan todas las categorías (llenando con 0 si falta)
ventas_tienda1_completo = ventas_por_categoria_tienda1.reindex(categorias_unicas, fill_value=0).tolist()
ventas_tienda2_completo = ventas_por_categoria_tienda2.reindex(categorias_unicas, fill_value=0).tolist()
ventas_tienda3_completo = ventas_por_categoria_tienda3.reindex(categorias_unicas, fill_value=0).tolist()
ventas_tienda4_completo = ventas_por_categoria_tienda4.reindex(categorias_unicas, fill_value=0).tolist()

# Crear el gráfico de radar
labels = np.array(categorias_unicas)
angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()

# Cerrar el círculo
angles += angles[:1]
ventas_tienda1_completo += ventas_tienda1_completo[:1]
ventas_tienda2_completo += ventas_tienda2_completo[:1]
ventas_tienda3_completo += ventas_tienda3_completo[:1]
ventas_tienda4_completo += ventas_tienda4_completo[:1]

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))

ax.plot(angles, ventas_tienda1_completo, linewidth=2, label='Tienda 1')
ax.plot(angles, ventas_tienda2_completo, linewidth=2, label='Tienda 2')
ax.plot(angles, ventas_tienda3_completo, linewidth=2, label='Tienda 3')
ax.plot(angles, ventas_tienda4_completo, linewidth=2, label='Tienda 4')

ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)

# Etiquetas de las categorías
ax.set_thetagrids(np.degrees(angles[:-1]), labels)

# Ajustar los límites del gráfico
max_venta = max(max(ventas_tienda1_completo), max(ventas_tienda2_completo), max(ventas_tienda3_completo), max(ventas_tienda4_completo))
ax.set_ylim(0, max_venta * 1.2)

# Título del gráfico
plt.title('Comparación de Frecuencia de Productos por Categoría (Todas las Tiendas)', pad=40)

# Leyenda
ax.legend(loc='upper right', bbox_to_anchor=(1.1, 1.1))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Calcula la calificación promedio para la tienda 1
calificacion_promedio_tienda1 = tienda['Calificación'].mean()
print('Calificación promedio de la tienda 1: ' + str(round(calificacion_promedio_tienda1,3)))
# Out:
# Calificación promedio de la tienda 1: 3.977

# %%
# Calcula la calificación promedio para la tienda 2
calificacion_promedio_tienda2 = tienda2['Calificación'].mean()
print('Calificación promedio de la tienda 2: ' + str(round(calificacion_promedio_tienda2,3)))
# Out:
# Calificación promedio de la tienda 2: 4.037

# %%
# Calcula la calificación promedio para la tienda 3
calificacion_promedio_tienda3 = tienda3['Calificación'].mean()
print('Calificación promedio de la tienda 3: ' + str(round(calificacion_promedio_tienda3,3)))
# Out:
# Calificación promedio de la tienda 3: 4.048

# %%
# Calcula la calificación promedio para la tienda 4
calificacion_promedio_tienda4 = tienda4['Calificación'].mean()
print('Calificación promedio de la tienda 4: ' + str(round(calificacion_promedio_tienda4,3)))
# Out:
# Calificación promedio de la tienda 4: 3.996

# %%
# Datos de calificaciones promedio
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
calificaciones_promedio = [calificacion_promedio_tienda1, calificacion_promedio_tienda2, calificacion_promedio_tienda3, calificacion_promedio_tienda4]

# Crear el gráfico de líneas
plt.plot(tiendas, calificaciones_promedio, marker='o')
plt.ylim(3.75, 4.25)

# Agregar etiquetas y título
plt.xlabel('Tiendas')
plt.ylabel('Calificación Promedio')
plt.title('Calificaciones Promedio de las Tiendas')

# Mostrar la cuadrícula
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
"""
Función para encontrar el producto más vendido y el menos vendido en cada tienda
@param df: DataFrame de la tienda
@param tienda_num: Número de la tienda
"""
def best_selling_products(df, tienda_num):
    # Agrupa por nombre de producto y suma las cantidades vendidas
    product_sales = df['Producto'].value_counts()
    # Ordena las ventas en orden descendente
    top_product = product_sales.sort_values(ascending=False)
    print(f"Tienda {tienda_num}:")
    print(f"Total de productos encontrados: {top_product.count()}")
    print("-" * 20)
    print("Top 5 productos más vendidos:\n")
    # Muestra los 5 productos más vendidos y sus cantidades
    for i in range(min(5, len(top_product))):
        print(f"Producto {i+1}:")
        print(f"{top_product.index[i]}\nCantidad vendida: {top_product.values[i]}\n")
    print("-" * 20)
    print("Top 5 productos menos vendidos:\n")
    # Muestra los 5 productos menos vendidos y sus cantidades
    for i in range(min(5, len(top_product))):
        print(f"Producto {i+1}:")
        print(f"{top_product.index[-(i+1)]}\nCantidad vendida: {top_product.values[-(i+1)]}\n")
    print("-" * 20)

# %%
"""Función para graficar los productos más y menos vendidos en cada tienda
@param df: DataFrame de la tienda
@param tienda_num: Número de la tienda
"""

def plot_product_sales(df, tienda_num):
    product_sales = df['Producto'].value_counts()
    top_products = product_sales.head(5)   # Top 5 productos mas vendidos
    bottom_products = product_sales.tail(5) # Top 5 productos menos vendidos

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    top_products.plot(kind='barh', color='skyblue')
    plt.title(f'Top 5 Productos mas vendidos - Tienda {tienda_num}')
    plt.xlabel('Cantidad vendida')
    plt.ylabel('')
    plt.yticks(rotation=0)
    plt.gca().invert_yaxis()


    plt.subplot(1, 2, 2)
    bottom_products.plot(kind='barh', color='lightcoral')
    plt.title(f'Top 5 Productos menos vendidos - Tienda {tienda_num}')
    plt.xlabel('Cantidad vendida')
    plt.ylabel('')
    plt.yticks(rotation=0)

    plt.tight_layout()
    plt.show()

# %%
print('Productos más y menos vendidos de la Tienda 1\n')
best_selling_products(tienda, 1)
# Graficando
plot_product_sales(tienda, 1)
# Out:
# Productos más y menos vendidos de la Tienda 1
#
# Tienda 1:
# Total de productos encontrados: 51
# --------------------
# Top 5 productos más vendidos:
#
# Producto 1:
# Microondas
# Cantidad vendida: 60
#
# Producto 2:
# TV LED UHD 4K
# Cantidad vendida: 60
#
# Producto 3:
# Armario
# Cantidad vendida: 60
#
# Producto 4:
# Secadora de ropa
# Cantidad vendida: 58
#
# Producto 5:
# Mesa de noche
# Cantidad vendida: 56
#
# --------------------
# Top 5 productos menos vendidos:
#
# Producto 1:
# Celular ABXY
# Cantidad vendida: 33
#
# Producto 2:
# Auriculares con micrófono
# Cantidad vendida: 33
#
# Producto 3:
# Olla de presión
# Cantidad vendida: 35
#
# Producto 4:
# Pandereta
# Cantidad vendida: 36
#
# Producto 5:
# Ciencia de datos con Python
# Cantidad vendida: 39
#
# --------------------

# %%
print('Productos más y menos vendidos de la Tienda 2\n')
best_selling_products(tienda2, 2)
# Graficando
plot_product_sales(tienda2, 2)
# Out:
# Productos más y menos vendidos de la Tienda 2
#
# Tienda 2:
# Total de productos encontrados: 51
# --------------------
# Top 5 productos más vendidos:
#
# Producto 1:
# Iniciando en programación
# Cantidad vendida: 65
#
# Producto 2:
# Microondas
# Cantidad vendida: 62
#
# Producto 3:
# Batería
# Cantidad vendida: 61
#
# Producto 4:
# Guitarra acústica
# Cantidad vendida: 58
#
# Producto 5:
# Pandereta
# Cantidad vendida: 58
#
# --------------------
# Top 5 productos menos vendidos:
#
# Producto 1:
# Juego de mesa
# Cantidad vendida: 32
#
# Producto 2:
# Impresora
# Cantidad vendida: 34
#
# Producto 3:
# Mesa de comedor
# Cantidad vendida: 34
#
# Producto 4:
# Sillón
# Cantidad vendida: 35
#
# Producto 5:
# Auriculares
# Cantidad vendida: 37
#
# --------------------

# %%
print('Productos más y menos vendidos de la Tienda 3\n')
best_selling_products(tienda3, 3)
# Graficando
plot_product_sales(tienda3, 3)
# Out:
# Productos más y menos vendidos de la Tienda 3
#
# Tienda 3:
# Total de productos encontrados: 51
# --------------------
# Top 5 productos más vendidos:
#
# Producto 1:
# Kit de bancas
# Cantidad vendida: 57
#
# Producto 2:
# Mesa de comedor
# Cantidad vendida: 56
#
# Producto 3:
# Cama king
# Cantidad vendida: 56
#
# Producto 4:
# Set de ollas
# Cantidad vendida: 55
#
# Producto 5:
# Mesa de noche
# Cantidad vendida: 55
#
# --------------------
# Top 5 productos menos vendidos:
#
# Producto 1:
# Bloques de construcción
# Cantidad vendida: 35
#
# Producto 2:
# Microondas
# Cantidad vendida: 36
#
# Producto 3:
# Mochila
# Cantidad vendida: 36
#
# Producto 4:
# Set de vasos
# Cantidad vendida: 36
#
# Producto 5:
# Guitarra eléctrica
# Cantidad vendida: 38
#
# --------------------

# %%
print('Productos más y menos vendidos de la Tienda 4\n')
best_selling_products(tienda4, 4)
# Graficando
plot_product_sales(tienda4, 4)
# Out:
# Productos más y menos vendidos de la Tienda 4
#
# Tienda 4:
# Total de productos encontrados: 51
# --------------------
# Top 5 productos más vendidos:
#
# Producto 1:
# Cama box
# Cantidad vendida: 62
#
# Producto 2:
# Cubertería
# Cantidad vendida: 59
#
# Producto 3:
# Dashboards con Power BI
# Cantidad vendida: 56
#
# Producto 4:
# Cama king
# Cantidad vendida: 56
#
# Producto 5:
# Carrito de control remoto
# Cantidad vendida: 55
#
# --------------------
# Top 5 productos menos vendidos:
#
# Producto 1:
# Guitarra eléctrica
# Cantidad vendida: 33
#
# Producto 2:
# Armario
# Cantidad vendida: 34
#
# Producto 3:
# Guitarra acústica
# Cantidad vendida: 37
#
# Producto 4:
# Ciencia de datos con Python
# Cantidad vendida: 38
#
# Producto 5:
# Refrigerador
# Cantidad vendida: 38
#
# --------------------

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
# Calculando el costo de envío promedio
costo_envio_promedio_tienda1 = tienda['Costo de envío'].mean()
# Resultado redondeado a 2 dígitos
print('Costo de envío promedio de la tienda 1: ' + str(round(costo_envio_promedio_tienda1,2)))
# Out:
# Costo de envío promedio de la tienda 1: 26018.61

# %%
# Calculando el costo de envío promedio
costo_envio_promedio_tienda2 = tienda2['Costo de envío'].mean()
# Resultado redondeado a 2 dígitos
print('Costo de envío promedio de la tienda 2: ' + str(round(costo_envio_promedio_tienda2,2)))
# Out:
# Costo de envío promedio de la tienda 2: 25216.24

# %%
# Calculando el costo de envío promedio
costo_envio_promedio_tienda3 = tienda3['Costo de envío'].mean()
# Resultado redondeado a 2 dígitos
print('Costo de envío promedio de la tienda 3: ' + str(round(costo_envio_promedio_tienda3,2)))
# Out:
# Costo de envío promedio de la tienda 3: 24805.68

# %%
# Calculando el costo de envío promedio
costo_envio_promedio_tienda4 = tienda4['Costo de envío'].mean()
# Resultado redondeado a 2 dígitos
print('Costo de envío promedio de la tienda 4: ' + str(round(costo_envio_promedio_tienda4,2)))
# Out:
# Costo de envío promedio de la tienda 4: 23459.46

# %%
# Datos de costos de envío promedio
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
costos_envio_promedio = [costo_envio_promedio_tienda1, costo_envio_promedio_tienda2, costo_envio_promedio_tienda3, costo_envio_promedio_tienda4]

# Crear el gráfico de puntos
plt.figure(figsize=(8, 6))
plt.scatter(tiendas, costos_envio_promedio, s=100, c='skyblue', marker='o', edgecolors='black')
plt.ylim(20000,30000)

# Añadir etiquetas y título
plt.xlabel('Tienda')
plt.ylabel('Costo de Envío Promedio')
plt.title('Costo de Envío Promedio por Tienda')

# Añadir una cuadrícula
plt.grid(True, linestyle='--', alpha=0.7)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Extra: Análisis de desempeño geográfico

# %%
# Combinando todas las tiendas
todas_las_tiendas = pd.concat([tienda, tienda2, tienda3, tienda4], ignore_index=True)

# Creando el mapa de calor
plt.figure(figsize=(10, 8))
sns.heatmap(todas_las_tiendas[['lat', 'lon']].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Latitude and Longitude')
plt.show()


# Visualización alternativa para un mejor análisis
plt.figure(figsize=(10,8))
sns.kdeplot(x='lon', y='lat', data=todas_las_tiendas, cmap="Reds", shade=True)
plt.title('Densidad de Distribución Geográfica de Ventas')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
# <ipython-input-29-1dd74fa27bba>:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x='lon', y='lat', data=todas_las_tiendas, cmap="Reds", shade=True)

# %%
# Creando gráfico de dispersión
plt.figure(figsize=(10, 6))
plt.scatter(todas_las_tiendas['lon'], todas_las_tiendas['lat'], alpha=0.5)
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.title('Geographic Distribution of Sales')
plt.grid(True)
plt.show()

# %%
# Creando el mapa, centrándolo en la media de la latitud y longitud de todas las tiendas
mapa_tiendas = folium.Map(location=[todas_las_tiendas['lat'].mean(), todas_las_tiendas['lon'].mean()], zoom_start=6)

# Agregando los marcadores
for index, row in todas_las_tiendas.iterrows():
    folium.Marker([row['lat'], row['lon']]).add_to(mapa_tiendas)

# Mosatrando el mapa
mapa_tiendas
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
